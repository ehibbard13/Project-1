# %%
# Dependencies
import hvplot.pandas
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
import json
from citipy import citipy
import numpy as np
# Import the API key
from config import geoapify_key

# %% [markdown]
# # New York, New York

# %%
url_NY = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:517bd8384d167e52c059afb076b00e634440f00101f901a5f2260000000000c0020992030f4e657720596f726b20436f756e7479&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_NY)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -73.93159527975197,
#                     40.79489738791445
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "East River Plaza Garage",
#                 "address_line2": "520 East 117th Street, New York, NY 10035, United States of America",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "building",
#                     "building.parking",
#                     "fee",
#                     "parking",
#                     "parking.cars",
#                     "parking.multistorey"
#                 ],
#                 "city": "New York",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "New York County",
#                 "datasource": {
# ...

# %%
for parks_ny in parking_data["features"]:
    try:
        print(parks_ny["properties"]["name"])
        print(parks_ny["properties"]["address_line2"]) 
        print(parks_ny["properties"]["datasource"]["raw"]["access"]) 
        print(parks_ny["properties"]["datasource"]["raw"]["parking"])
        print(parks_ny["properties"]["datasource"]["raw"]["fee"])
        print(parks_ny["properties"]["datasource"]["raw"]["capacity"])
   
    except:
        pass
 
       
    print("*"*20)
# Out:
# Equinox Fitness
# 1835 Sepulveda Boulevard, Los Angeles, CA 90025, United States of America
# customers
# multi-storey
# ********************
# Parking Lot F5
# Matador Way, Los Angeles, CA 91325, United States of America
# customers
# surface
# yes
# ********************
# P-6
# World Way, Los Angeles, CA 90009, United States of America
# ********************
# P-3
# World Way, Los Angeles, CA 90009, United States of America
# yes
# multi-storey
# yes
# ********************
# P-4
# World Way, Los Angeles, CA 90245, United States of America
# yes
# multi-storey
# yes
# ********************
# Sherman Oaks Galleria
# San Diego Freeway, Los Angeles, CA 91403, United States of America
# ********************
# Metro Park and Ride
# South La Cienega Boulevard, Los Angeles, CA 90250, United States of America
# yes
# multi-storey
# no
# ********************
# Restricted Lot F4
# Vincennes Street, Los Angeles, CA 91330, United States of America
# private
# surface
# yes
# ...

# %%
name = (parks_ny["properties"]["name"])
address = (parks_ny["properties"]["address_line2"])
access = (parks_ny["properties"]["datasource"]["raw"]["access"])
fee = (parks_ny["properties"]["datasource"]["raw"]["fee"])
Type = (parks_ny["properties"]["datasource"]["raw"]["parking"])
#capacity = (park["properties"]["datasource"]["raw"]["capacity"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 name = (parks_ny["properties"]["name"])
#       2 address = (parks_ny["properties"]["address_line2"])
#       3 access = (parks_ny["properties"]["datasource"]["raw"]["access"])
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
# ...

# %%
parking_df = pd.DataFrame()

parking_df["Name"]= ""
parking_df["Address"]= ""
parking_df["Access"] = ""
parking_df["Fee"] = ""
parking_df["Type"]=""
parking_df["Capacity"]=""

parking_df
# Out:
# Empty DataFrame
# Columns: [Name, Address, Access, Fee, Type, Capacity]
# Index: []

# %% [markdown]
# # Los Angeles, California

# %%
url_LA = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:5151f935f90f9a5dc059ec5ce2bd750b4140f00101f901ff29030000000000c0020692030b4c6f7320416e67656c6573&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_LA)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -118.44295102600427,
#                     34.045504712728324
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Equinox Fitness",
#                 "address_line2": "1835 Sepulveda Boulevard, Los Angeles, CA 90025, United States of America",
#                 "categories": [
#                     "access_limited",
#                     "access_limited.customers",
#                     "building",
#                     "building.parking",
#                     "parking",
#                     "parking.cars",
#                     "parking.multistorey"
#                 ],
#                 "city": "Los Angeles",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Los Angeles County",
#                 "datasource": {
# ...

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        #print("NA")
    #print("*"*20)
# Out:
# Equinox Fitness
# 1835 Sepulveda Boulevard, Los Angeles, CA 90025, United States of America
# customers
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 6
#       4 print(park["properties"]["address_line2"])
#       5 print(park["properties"]["datasource"]["raw"]["access"])
# ----> 6 print(park["properties"]["datasource"]["raw"]["fee"])
#       7 print(park["properties"]["datasource"]["raw"]["parking"])
#       8 print(park["properties"]["datasource"]["raw"]["capacity"])
#
# KeyError: 'fee'

# %% [markdown]
# # Chicago, Illinois

# %%
url_CHI = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:51a6c49a45e4eb55c0595a1990664ceb4440f00101f901ecde010000000000c002069203074368696361676f&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_CHI)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Houston, Texas

# %%
url_HOU = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:519bc800fa0fd857c0597523e5cbc5c63d40f00101f9018f07290000000000c00206920307486f7573746f6e&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_HOU)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park_Hou in parking_data["features"]:
    try:
        print(park_Hou["properties"]["name"])
        print(park_Hou["properties"]["address_line2"])
        print(park_Hou["properties"]["datasource"]["raw"]["access"])
        print(park_Hou["properties"]["datasource"]["raw"]["fee"])
        print(park_Hou["properties"]["datasource"]["raw"]["parking"])
        print(park_Hou["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Fort Worth, Texas

# %%
url_FORT = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:512b903aab385658c059df25b52d0e644040f00101f9014ac2010000000000c0020692030a466f727420576f727468&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_FORT)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Miami, Florida

# %%
url_MI = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:513497aaa46d0d54c059f33cfd817cc63940f00101f90101911200000000009203054d69616d69&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_MI)
parking_data_MI = response.json()
print(json.dumps(parking_data_MI, indent = 4, sort_keys = True))

# %%
for park_MI in parking_data_MI["features"]:
    try:
        print(park_MI["properties"]["name"])
        print(park_MI["properties"]["address_line2"])
        print(park_MI["properties"]["datasource"]["raw"]["access"])
        print(park_MI["properties"]["datasource"]["raw"]["fee"])
        print(park_MI["properties"]["datasource"]["raw"]["parking"])
        print(park_MI["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Atlanta, Georgia

# %%
url_Atl = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:51fc8114f40e1b55c059eb5631899de14040f00101f90105d3010000000000c0020692030741746c616e7461&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_Atl)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Philadelphia, Pennsylvania

# %%
url_Phi = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:51d80144b194c852c0590b89d6a9f9004440f00101f90176de020000000000c0020692030c5068696c6164656c70686961&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_Phi)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Washington, D.C.

# %%
url_DC = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:51e2067c7e184153c059b6be4868cb694340c00208e2031d77686f736f6e66697273743a6c6f63616c6974793a3835393331373739&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_DC)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)

# %% [markdown]
# # Phoenix, Arizona

# %%
url_PHO = f"https://api.geoapify.com/v2/places?categories=parking&filter=place:518ceee3f2b6055cc059373e2c342dc94040f00101f90199b2010000000000c0020692030750686f656e6978&limit=20&apiKey=eefb98014bc34193948d99ae46499e37"
response = requests.get(url_PHO)
parking_data = response.json()
print(json.dumps(parking_data, indent = 4, sort_keys = True))

# %%
for park in parking_data["features"]:
    try:
        print(park["properties"]["name"])
        print(park["properties"]["address_line2"])
        print(park["properties"]["datasource"]["raw"]["access"])
        print(park["properties"]["datasource"]["raw"]["fee"])
        print(park["properties"]["datasource"]["raw"]["parking"])
        print(park["properties"]["datasource"]["raw"]["capacity"])
    except (KeyError, IndexError):
        print("NA")
    print("*"*20)
